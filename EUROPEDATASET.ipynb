# %%
# !pip install openmeteo-requests
# !pip install requests-cache retry-requests numpy pandas
# Out:
# Collecting openmeteo-requests
#   Downloading openmeteo_requests-1.7.4-py3-none-any.whl.metadata (11 kB)
# Collecting niquests>=3.15.2 (from openmeteo-requests)
#   Downloading niquests-3.15.2-py3-none-any.whl.metadata (16 kB)
# Collecting openmeteo-sdk>=1.22.0 (from openmeteo-requests)
#   Downloading openmeteo_sdk-1.23.0-py3-none-any.whl.metadata (935 bytes)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from niquests>=3.15.2->openmeteo-requests) (3.4.4)
# Collecting urllib3-future<3,>=2.13.903 (from niquests>=3.15.2->openmeteo-requests)
#   Downloading urllib3_future-2.14.908-py3-none-any.whl.metadata (16 kB)
# Collecting wassima<3,>=1.0.1 (from niquests>=3.15.2->openmeteo-requests)
#   Downloading wassima-2.0.2-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: flatbuffers==25.9.23 in /usr/local/lib/python3.12/dist-packages (from openmeteo-sdk>=1.22.0->openmeteo-requests) (25.9.23)
# Requirement already satisfied: h11<1.0.0,>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from urllib3-future<3,>=2.13.903->niquests>=3.15.2->openmeteo-requests) (0.16.0)
# Collecting jh2<6.0.0,>=5.0.3 (from urllib3-future<3,>=2.13.903->niquests>=3.15.2->openmeteo-requests)
#   Downloading jh2-5.0.10-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting qh3<2.0.0,>=1.5.4 (from urllib3-future<3,>=2.13.903->niquests>=3.15.2->openmeteo-requests)
#   Downloading qh3-1.5.6-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.8 kB)
# Downloading openmeteo_requests-1.7.4-py3-none-any.whl (7.0 kB)
# Downloading niquests-3.15.2-py3-none-any.whl (167 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.1/167.1 kB 6.8 MB/s eta 0:00:00
# Downloading openmeteo_sdk-1.23.0-py3-none-any.whl (18 kB)
# Downloading urllib3_future-2.14.908-py3-none-any.whl (683 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 683.2/683.2 kB 12.2 MB/s eta 0:00:00
# Downloading wassima-2.0.2-py3-none-any.whl (145 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.8/145.8 kB 3.4 MB/s eta 0:00:00
# Downloading jh2-5.0.10-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (394 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 394.1/394.1 kB 14.3 MB/s eta 0:00:00
# Downloading qh3-1.5.6-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 20.4 MB/s eta 0:00:00
# Installing collected packages: wassima, qh3, openmeteo-sdk, jh2, urllib3-future, niquests, openmeteo-requests
# Successfully installed jh2-5.0.10 niquests-3.15.2 openmeteo-requests-1.7.4 openmeteo-sdk-1.23.0 qh3-1.5.6 urllib3-future-2.14.908 wassima-2.0.2
# Collecting requests-cache
#   Downloading requests_cache-1.2.1-py3-none-any.whl.metadata (9.9 kB)
# Collecting retry-requests
#   Downloading retry_requests-2.0.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.12/dist-packages (from requests-cache) (25.4.0)
# Collecting cattrs>=22.2 (from requests-cache)
#   Downloading cattrs-25.3.0-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests-cache) (4.5.0)
# Requirement already satisfied: requests>=2.22 in /usr/local/lib/python3.12/dist-packages (from requests-cache) (2.32.4)
# Collecting url-normalize>=1.4 (from requests-cache)
#   Downloading url_normalize-2.2.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: urllib3>=1.25.5 in /usr/local/lib/python3.12/dist-packages (from requests-cache) (2.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: typing-extensions>=4.14.0 in /usr/local/lib/python3.12/dist-packages (from cattrs>=22.2->requests-cache) (4.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.22->requests-cache) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.22->requests-cache) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.22->requests-cache) (2025.11.12)
# Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 4.2 MB/s eta 0:00:00
# Downloading retry_requests-2.0.0-py3-none-any.whl (15 kB)
# Downloading cattrs-25.3.0-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.7/70.7 kB 5.1 MB/s eta 0:00:00
# Downloading url_normalize-2.2.1-py3-none-any.whl (14 kB)
# Installing collected packages: url-normalize, cattrs, retry-requests, requests-cache
# Successfully installed cattrs-25.3.0 requests-cache-1.2.1 retry-requests-2.0.0 url-normalize-2.2.1

# %%
import pandas as pd

# %% [markdown]
# #Berlin

# %%
import openmeteo_requests

import pandas as pd
import requests_cache
from retry_requests import retry

# Setup the Open-Meteo API client with cache and retry on error
cache_session = requests_cache.CachedSession('.cache', expire_after = 3600)
retry_session = retry(cache_session, retries = 5, backoff_factor = 0.2)
openmeteo = openmeteo_requests.Client(session = retry_session)

# Make sure all required weather variables are listed here
# The order of variables in hourly or daily is important to assign them correctly below
url = "https://air-quality-api.open-meteo.com/v1/air-quality"
params = {
	"latitude": 52.5244,
	"longitude": 13.4105,
	"hourly": ["pm10", "pm2_5", "ammonia", "carbon_monoxide", "nitrogen_dioxide", "carbon_dioxide", "sulphur_dioxide", "methane"],
	"current": "ozone",
	"timezone": "GMT",
	"start_date": "2020-12-01",
	"end_date": "2025-12-01",
}
responses = openmeteo.weather_api(url, params=params)

# Process first location. Add a for-loop for multiple locations or weather models
response = responses[0]
print(f"Coordinates: {response.Latitude()}°N {response.Longitude()}°E")
print(f"Elevation: {response.Elevation()} m asl")
print(f"Timezone: {response.Timezone()}{response.TimezoneAbbreviation()}")
print(f"Timezone difference to GMT+0: {response.UtcOffsetSeconds()}s")

# Process current data. The order of variables needs to be the same as requested.
current = response.Current()
current_ozone = current.Variables(0).Value()

print(f"\nCurrent time: {current.Time()}")
print(f"Current ozone: {current_ozone}")

# Process hourly data. The order of variables needs to be the same as requested.
hourly = response.Hourly()
hourly_pm10 = hourly.Variables(0).ValuesAsNumpy()
hourly_pm2_5 = hourly.Variables(1).ValuesAsNumpy()
hourly_ammonia = hourly.Variables(2).ValuesAsNumpy()
hourly_carbon_monoxide = hourly.Variables(3).ValuesAsNumpy()
hourly_nitrogen_dioxide = hourly.Variables(4).ValuesAsNumpy()
hourly_carbon_dioxide = hourly.Variables(5).ValuesAsNumpy()
hourly_sulphur_dioxide = hourly.Variables(6).ValuesAsNumpy()
hourly_methane = hourly.Variables(7).ValuesAsNumpy()

hourly_data = {"date": pd.date_range(
	start = pd.to_datetime(hourly.Time(), unit = "s", utc = True),
	end =  pd.to_datetime(hourly.TimeEnd(), unit = "s", utc = True),
	freq = pd.Timedelta(seconds = hourly.Interval()),
	inclusive = "left"
)}

hourly_data["pm10"] = hourly_pm10
hourly_data["pm2_5"] = hourly_pm2_5
hourly_data["ammonia"] = hourly_ammonia
hourly_data["carbon_monoxide"] = hourly_carbon_monoxide
hourly_data["nitrogen_dioxide"] = hourly_nitrogen_dioxide
hourly_data["carbon_dioxide"] = hourly_carbon_dioxide
hourly_data["sulphur_dioxide"] = hourly_sulphur_dioxide
hourly_data["methane"] = hourly_methane

Berlin = pd.DataFrame(data = hourly_data)
print("\nHourly data\n", Berlin)

# %%
Berlin.to_csv('Berlin.csv', index=False)

# %% [markdown]
# #London

# %%
import openmeteo_requests

import pandas as pd
import requests_cache
from retry_requests import retry

# Setup the Open-Meteo API client with cache and retry on error
cache_session = requests_cache.CachedSession('.cache', expire_after = 3600)
retry_session = retry(cache_session, retries = 5, backoff_factor = 0.2)
openmeteo = openmeteo_requests.Client(session = retry_session)

# Make sure all required weather variables are listed here
# The order of variables in hourly or daily is important to assign them correctly below
url = "https://air-quality-api.open-meteo.com/v1/air-quality"
params = {
	"latitude": 51.5085,
	"longitude": -0.1257,
	"hourly": ["pm10", "pm2_5", "ammonia", "carbon_monoxide", "nitrogen_dioxide", "carbon_dioxide", "sulphur_dioxide", "methane"],
	"current": "ozone",
	"timezone": "GMT",
	"start_date": "2020-12-01",
	"end_date": "2025-12-01",
}
responses = openmeteo.weather_api(url, params=params)

# Process first location. Add a for-loop for multiple locations or weather models
response = responses[0]
print(f"Coordinates: {response.Latitude()}°N {response.Longitude()}°E")
print(f"Elevation: {response.Elevation()} m asl")
print(f"Timezone: {response.Timezone()}{response.TimezoneAbbreviation()}")
print(f"Timezone difference to GMT+0: {response.UtcOffsetSeconds()}s")

# Process current data. The order of variables needs to be the same as requested.
current = response.Current()
current_ozone = current.Variables(0).Value()

print(f"\nCurrent time: {current.Time()}")
print(f"Current ozone: {current_ozone}")

# Process hourly data. The order of variables needs to be the same as requested.
hourly = response.Hourly()
hourly_pm10 = hourly.Variables(0).ValuesAsNumpy()
hourly_pm2_5 = hourly.Variables(1).ValuesAsNumpy()
hourly_ammonia = hourly.Variables(2).ValuesAsNumpy()
hourly_carbon_monoxide = hourly.Variables(3).ValuesAsNumpy()
hourly_nitrogen_dioxide = hourly.Variables(4).ValuesAsNumpy()
hourly_carbon_dioxide = hourly.Variables(5).ValuesAsNumpy()
hourly_sulphur_dioxide = hourly.Variables(6).ValuesAsNumpy()
hourly_methane = hourly.Variables(7).ValuesAsNumpy()

hourly_data = {"date": pd.date_range(
	start = pd.to_datetime(hourly.Time(), unit = "s", utc = True),
	end =  pd.to_datetime(hourly.TimeEnd(), unit = "s", utc = True),
	freq = pd.Timedelta(seconds = hourly.Interval()),
	inclusive = "left"
)}

hourly_data["pm10"] = hourly_pm10
hourly_data["pm2_5"] = hourly_pm2_5
hourly_data["ammonia"] = hourly_ammonia
hourly_data["carbon_monoxide"] = hourly_carbon_monoxide
hourly_data["nitrogen_dioxide"] = hourly_nitrogen_dioxide
hourly_data["carbon_dioxide"] = hourly_carbon_dioxide
hourly_data["sulphur_dioxide"] = hourly_sulphur_dioxide
hourly_data["methane"] = hourly_methane

London = pd.DataFrame(data = hourly_data)
print("\nHourly data\n", London)
# Out:
# Coordinates: 51.5°N -0.10000038146972656°E
# Elevation: 23.0 m asl
# Timezone: NoneNone
# Timezone difference to GMT+0: 0s
#
# Current time: 1765191600
# Current ozone: 48.0
#
# Hourly data
#                             date  pm10  pm2_5  ammonia  carbon_monoxide  \
# 0     2020-12-01 00:00:00+00:00   7.4    4.0      1.1            213.0
# 1     2020-12-01 01:00:00+00:00   7.4    5.0      1.2            206.0
# 2     2020-12-01 02:00:00+00:00   7.4    4.7      1.2            197.0
# 3     2020-12-01 03:00:00+00:00   7.6    4.4      0.7            193.0
# 4     2020-12-01 04:00:00+00:00   7.0    4.2      0.5            186.0
# ...                         ...   ...    ...      ...              ...
# 43843 2025-12-01 19:00:00+00:00   8.9    4.2      1.6            148.0
# 43844 2025-12-01 20:00:00+00:00   8.4    3.8      1.1            146.0
# 43845 2025-12-01 21:00:00+00:00   8.7    3.7      1.1            141.0
# 43846 2025-12-01 22:00:00+00:00   5.9    3.1      0.8            141.0
# 43847 2025-12-01 23:00:00+00:00   4.2    2.6      0.8            142.0
#
#        nitrogen_dioxide  carbon_dioxide  sulphur_dioxide  methane
# 0                  12.8             NaN              2.7      NaN
# 1                  12.9             NaN              3.1      NaN
# 2                  12.3             NaN              3.1      NaN
# 3                  10.4             NaN              2.8      NaN
# 4                  10.0             NaN              3.2      NaN
# ...                 ...             ...              ...      ...
# 43843              14.5           447.0              1.3   1409.0
# 43844              12.3           447.0              1.1   1412.0
# 43845              11.3           447.0              1.1   1412.0
# 43846              11.1           447.0              0.9   1405.0
# 43847              10.7           447.0              0.7   1394.0
#
# [43848 rows x 9 columns]

# %%
London.to_csv('London.csv', index=False)

# %% [markdown]
# #Moscow

# %%
import openmeteo_requests

import pandas as pd
import requests_cache
from retry_requests import retry

# Setup the Open-Meteo API client with cache and retry on error
cache_session = requests_cache.CachedSession('.cache', expire_after = 3600)
retry_session = retry(cache_session, retries = 5, backoff_factor = 0.2)
openmeteo = openmeteo_requests.Client(session = retry_session)

# Make sure all required weather variables are listed here
# The order of variables in hourly or daily is important to assign them correctly below
url = "https://air-quality-api.open-meteo.com/v1/air-quality"
params = {
	"latitude": 55.7522,
	"longitude": 37.6156,
	"hourly": ["pm10", "pm2_5", "ammonia", "carbon_monoxide", "nitrogen_dioxide", "carbon_dioxide", "sulphur_dioxide", "methane"],
	"current": "ozone",
	"timezone": "GMT",
	"start_date": "2020-12-01",
	"end_date": "2025-12-01",
}
responses = openmeteo.weather_api(url, params=params)

# Process first location. Add a for-loop for multiple locations or weather models
response = responses[0]
print(f"Coordinates: {response.Latitude()}°N {response.Longitude()}°E")
print(f"Elevation: {response.Elevation()} m asl")
print(f"Timezone: {response.Timezone()}{response.TimezoneAbbreviation()}")
print(f"Timezone difference to GMT+0: {response.UtcOffsetSeconds()}s")

# Process current data. The order of variables needs to be the same as requested.
current = response.Current()
current_ozone = current.Variables(0).Value()

print(f"\nCurrent time: {current.Time()}")
print(f"Current ozone: {current_ozone}")

# Process hourly data. The order of variables needs to be the same as requested.
hourly = response.Hourly()
hourly_pm10 = hourly.Variables(0).ValuesAsNumpy()
hourly_pm2_5 = hourly.Variables(1).ValuesAsNumpy()
hourly_ammonia = hourly.Variables(2).ValuesAsNumpy()
hourly_carbon_monoxide = hourly.Variables(3).ValuesAsNumpy()
hourly_nitrogen_dioxide = hourly.Variables(4).ValuesAsNumpy()
hourly_carbon_dioxide = hourly.Variables(5).ValuesAsNumpy()
hourly_sulphur_dioxide = hourly.Variables(6).ValuesAsNumpy()
hourly_methane = hourly.Variables(7).ValuesAsNumpy()

hourly_data = {"date": pd.date_range(
	start = pd.to_datetime(hourly.Time(), unit = "s", utc = True),
	end =  pd.to_datetime(hourly.TimeEnd(), unit = "s", utc = True),
	freq = pd.Timedelta(seconds = hourly.Interval()),
	inclusive = "left"
)}

hourly_data["pm10"] = hourly_pm10
hourly_data["pm2_5"] = hourly_pm2_5
hourly_data["ammonia"] = hourly_ammonia
hourly_data["carbon_monoxide"] = hourly_carbon_monoxide
hourly_data["nitrogen_dioxide"] = hourly_nitrogen_dioxide
hourly_data["carbon_dioxide"] = hourly_carbon_dioxide
hourly_data["sulphur_dioxide"] = hourly_sulphur_dioxide
hourly_data["methane"] = hourly_methane

Moscow = pd.DataFrame(data = hourly_data)
print("\nHourly data\n", Moscow)
# Out:
# Coordinates: 55.80000305175781°N 37.60000228881836°E
# Elevation: 141.0 m asl
# Timezone: NoneNone
# Timezone difference to GMT+0: 0s
#
# Current time: 1765191600
# Current ozone: 5.0
#
# Hourly data
#                             date       pm10      pm2_5  ammonia  \
# 0     2020-12-01 00:00:00+00:00  21.700001  17.700001      0.2
# 1     2020-12-01 01:00:00+00:00  26.900000  19.600000      0.3
# 2     2020-12-01 02:00:00+00:00  26.900000  18.799999      0.3
# 3     2020-12-01 03:00:00+00:00  25.100000  17.600000      0.3
# 4     2020-12-01 04:00:00+00:00  25.000000  19.500000      0.3
# ...                         ...        ...        ...      ...
# 43843 2025-12-01 19:00:00+00:00  69.300003  58.299999      1.0
# 43844 2025-12-01 20:00:00+00:00  67.099998  55.799999      1.0
# 43845 2025-12-01 21:00:00+00:00  62.700001  52.099998      0.8
# 43846 2025-12-01 22:00:00+00:00  60.000000  48.599998      0.5
# 43847 2025-12-01 23:00:00+00:00  59.599998  45.799999      0.4
#
#        carbon_monoxide  nitrogen_dioxide  carbon_dioxide  sulphur_dioxide  \
# 0                221.0         24.100000             NaN        26.700001
# 1                237.0         25.799999             NaN        33.700001
# 2                244.0         25.600000             NaN        34.000000
# 3                242.0         29.700001             NaN        32.700001
# 4                245.0         30.500000             NaN        34.099998
# ...                ...               ...             ...              ...
# 43843            495.0         53.700001           500.0        81.300003
# 43844            416.0         50.400002           490.0        66.699997
# 43845            357.0         46.299999           483.0        52.700001
# 43846            317.0         42.900002           482.0        49.200001
# 43847            301.0         40.400002           484.0        48.400002
#
#        methane
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 43843   1815.0
# 43844   1780.0
# 43845   1776.0
# 43846   1830.0
# 43847   1915.0
#
# [43848 rows x 9 columns]

# %%
Moscow.to_csv('Moscow.csv', index=False)
