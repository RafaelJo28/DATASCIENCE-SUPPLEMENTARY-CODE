# %% [markdown]
# #Asia Analysis

# %%
jakarta_df = pd.read_csv('/content/Jakarta.csv')
print('\nJakarta Data:')
display(jakarta_df.head())
# Out:
# Jakarta Data:
#                         date  pm10  pm2_5  ammonia  carbon_monoxide  \
# 0  2020-12-01 00:00:00+00:00   NaN    NaN      NaN              NaN
# 1  2020-12-01 01:00:00+00:00   NaN    NaN      NaN              NaN
# 2  2020-12-01 02:00:00+00:00   NaN    NaN      NaN              NaN
# 3  2020-12-01 03:00:00+00:00   NaN    NaN      NaN              NaN
# 4  2020-12-01 04:00:00+00:00   NaN    NaN      NaN              NaN
#
#    nitrogen_dioxide  carbon_dioxide  sulphur_dioxide  methane
# 0               NaN             NaN              NaN      NaN
# 1               NaN             NaN              NaN      NaN
# 2               NaN             NaN              NaN      NaN
# 3               NaN             NaN              NaN      NaN
# 4               NaN             NaN              NaN      NaN

# %%
jakarta_df
# Out:
#                             date   pm10  pm2_5  ammonia  carbon_monoxide  \
# 0      2020-12-01 00:00:00+00:00    NaN    NaN      NaN              NaN
# 1      2020-12-01 01:00:00+00:00    NaN    NaN      NaN              NaN
# 2      2020-12-01 02:00:00+00:00    NaN    NaN      NaN              NaN
# 3      2020-12-01 03:00:00+00:00    NaN    NaN      NaN              NaN
# 4      2020-12-01 04:00:00+00:00    NaN    NaN      NaN              NaN
# ...                          ...    ...    ...      ...              ...
# 43843  2025-12-01 19:00:00+00:00   97.3   97.1      NaN            680.0
# 43844  2025-12-01 20:00:00+00:00   96.2   95.7      NaN            596.0
# 43845  2025-12-01 21:00:00+00:00   99.4   99.0      NaN            644.0
# 43846  2025-12-01 22:00:00+00:00  108.7  108.3      NaN            918.0
# 43847  2025-12-01 23:00:00+00:00  128.1  127.6      NaN           1325.0
#
#        nitrogen_dioxide  carbon_dioxide  sulphur_dioxide  methane
# 0                   NaN             NaN              NaN      NaN
# 1                   NaN             NaN              NaN      NaN
# 2                   NaN             NaN              NaN      NaN
# 3                   NaN             NaN              NaN      NaN
# 4                   NaN             NaN              NaN      NaN
# ...                 ...             ...              ...      ...
# 43843             140.0           454.0             58.7   1664.0
# 43844             135.0           454.0             59.4   1711.0
# 43845             131.0           455.0             61.2   1741.0
# 43846             131.8           456.0             66.5   1740.0
# 43847             133.6           458.0             73.0   1722.0
#
# [43848 rows x 9 columns]

# %%
bangkok_df = pd.read_csv('/content/Bangkok.csv')
print('\nBangkok Data:')
display(bangkok_df.head())
# Out:
# Bangkok Data:
#                         date  pm10  pm2_5  ammonia  carbon_monoxide  \
# 0  2020-12-01 00:00:00+00:00   NaN    NaN      NaN              NaN
# 1  2020-12-01 01:00:00+00:00   NaN    NaN      NaN              NaN
# 2  2020-12-01 02:00:00+00:00   NaN    NaN      NaN              NaN
# 3  2020-12-01 03:00:00+00:00   NaN    NaN      NaN              NaN
# 4  2020-12-01 04:00:00+00:00   NaN    NaN      NaN              NaN
#
#    nitrogen_dioxide  carbon_dioxide  sulphur_dioxide  methane
# 0               NaN             NaN              NaN      NaN
# 1               NaN             NaN              NaN      NaN
# 2               NaN             NaN              NaN      NaN
# 3               NaN             NaN              NaN      NaN
# 4               NaN             NaN              NaN      NaN

# %%
bangkok_df
# Out:
#                             date  pm10  pm2_5  ammonia  carbon_monoxide  \
# 0      2020-12-01 00:00:00+00:00   NaN    NaN      NaN              NaN
# 1      2020-12-01 01:00:00+00:00   NaN    NaN      NaN              NaN
# 2      2020-12-01 02:00:00+00:00   NaN    NaN      NaN              NaN
# 3      2020-12-01 03:00:00+00:00   NaN    NaN      NaN              NaN
# 4      2020-12-01 04:00:00+00:00   NaN    NaN      NaN              NaN
# ...                          ...   ...    ...      ...              ...
# 43843  2025-12-01 19:00:00+00:00  28.3   28.3      NaN            264.0
# 43844  2025-12-01 20:00:00+00:00  27.2   27.2      NaN            258.0
# 43845  2025-12-01 21:00:00+00:00  26.3   26.3      NaN            334.0
# 43846  2025-12-01 22:00:00+00:00  25.7   25.6      NaN            479.0
# 43847  2025-12-01 23:00:00+00:00  25.1   25.1      NaN            707.0
#
#        nitrogen_dioxide  carbon_dioxide  sulphur_dioxide  methane
# 0                   NaN             NaN              NaN      NaN
# 1                   NaN             NaN              NaN      NaN
# 2                   NaN             NaN              NaN      NaN
# 3                   NaN             NaN              NaN      NaN
# 4                   NaN             NaN              NaN      NaN
# ...                 ...             ...              ...      ...
# 43843              39.8           447.0             17.8   1599.0
# 43844              39.2           445.0             17.8   1604.0
# 43845              39.4           446.0             18.6   1614.0
# 43846              39.9           449.0             20.2   1624.0
# 43847              41.1           454.0             22.6   1639.0
#
# [43848 rows x 9 columns]

# %%
tokyo_df = pd.read_csv('/content/Tokyo.csv')
print('\nTokyo Data:')
display(tokyo_df.head())
# Out:
# Tokyo Data:
#                         date  pm10  pm2_5  ammonia  carbon_monoxide  \
# 0  2020-12-01 00:00:00+00:00   NaN    NaN      NaN              NaN
# 1  2020-12-01 01:00:00+00:00   NaN    NaN      NaN              NaN
# 2  2020-12-01 02:00:00+00:00   NaN    NaN      NaN              NaN
# 3  2020-12-01 03:00:00+00:00   NaN    NaN      NaN              NaN
# 4  2020-12-01 04:00:00+00:00   NaN    NaN      NaN              NaN
#
#    nitrogen_dioxide  carbon_dioxide  sulphur_dioxide  methane
# 0               NaN             NaN              NaN      NaN
# 1               NaN             NaN              NaN      NaN
# 2               NaN             NaN              NaN      NaN
# 3               NaN             NaN              NaN      NaN
# 4               NaN             NaN              NaN      NaN

# %%
tokyo_df
# Out:
#                             date  pm10  pm2_5  ammonia  carbon_monoxide  \
# 0      2020-12-01 00:00:00+00:00   NaN    NaN      NaN              NaN
# 1      2020-12-01 01:00:00+00:00   NaN    NaN      NaN              NaN
# 2      2020-12-01 02:00:00+00:00   NaN    NaN      NaN              NaN
# 3      2020-12-01 03:00:00+00:00   NaN    NaN      NaN              NaN
# 4      2020-12-01 04:00:00+00:00   NaN    NaN      NaN              NaN
# ...                          ...   ...    ...      ...              ...
# 43843  2025-12-01 19:00:00+00:00  39.6   38.9      NaN            437.0
# 43844  2025-12-01 20:00:00+00:00  36.7   35.9      NaN            435.0
# 43845  2025-12-01 21:00:00+00:00  38.4   37.7      NaN            434.0
# 43846  2025-12-01 22:00:00+00:00  42.8   42.1      NaN            430.0
# 43847  2025-12-01 23:00:00+00:00  42.7   41.7      NaN            426.0
#
#        nitrogen_dioxide  carbon_dioxide  sulphur_dioxide  methane
# 0                   NaN             NaN              NaN      NaN
# 1                   NaN             NaN              NaN      NaN
# 2                   NaN             NaN              NaN      NaN
# 3                   NaN             NaN              NaN      NaN
# 4                   NaN             NaN              NaN      NaN
# ...                 ...             ...              ...      ...
# 43843              80.2           490.0             56.6   1551.0
# 43844              78.6           494.0             55.8   1541.0
# 43845              76.0           496.0             54.9   1532.0
# 43846              72.7           496.0             53.9   1524.0
# 43847              68.6           494.0             52.8   1516.0
#
# [43848 rows x 9 columns]

# %% [markdown]
# JAKARTA CLEANING

# %%
import pandas as pd
import numpy as np

fn = "Jakarta.csv"
df = pd.read_csv(fn)

print("shape:", df.shape)
print("columns:", df.columns.tolist())
print(df.head(5))
print("\nmissing per column:\n", df.isna().sum())
# Out:
# shape: (43848, 9)
# columns: ['date', 'pm10', 'pm2_5', 'ammonia', 'carbon_monoxide', 'nitrogen_dioxide', 'carbon_dioxide', 'sulphur_dioxide', 'methane']
#                         date  pm10  pm2_5  ammonia  carbon_monoxide  \
# 0  2020-12-01 00:00:00+00:00   NaN    NaN      NaN              NaN
# 1  2020-12-01 01:00:00+00:00   NaN    NaN      NaN              NaN
# 2  2020-12-01 02:00:00+00:00   NaN    NaN      NaN              NaN
# 3  2020-12-01 03:00:00+00:00   NaN    NaN      NaN              NaN
# 4  2020-12-01 04:00:00+00:00   NaN    NaN      NaN              NaN
#
#    nitrogen_dioxide  carbon_dioxide  sulphur_dioxide  methane
# 0               NaN             NaN              NaN      NaN
# 1               NaN             NaN              NaN      NaN
# 2               NaN             NaN              NaN      NaN
# 3               NaN             NaN              NaN      NaN
# 4               NaN             NaN              NaN      NaN
#
# missing per column:
#  date                    0
# pm10                14664
# pm2_5               14664
# ammonia             43848
# carbon_monoxide     14664
# nitrogen_dioxide    14664
# carbon_dioxide      34200
# sulphur_dioxide     14664
# methane             34200
# dtype: int64

# %%
df.columns = (
    df.columns.str.strip()
              .str.lower()
              .str.replace(" ", "_")
              .str.replace("-", "_")
)

print(df.columns.tolist())
# Out:
# ['date', 'pm10', 'pm2_5', 'ammonia', 'carbon_monoxide', 'nitrogen_dioxide', 'carbon_dioxide', 'sulphur_dioxide', 'methane']

# %%
candidates = ["datetime", "date_time", "date", "time", "timestamp"]
dt_col = None

for c in candidates:
    if c in df.columns:
        dt_col = c
        break

if dt_col is None:
    raise RuntimeError("No datetime column found. Rename your column to one of: " + ", ".join(candidates))

df["datetime"] = pd.to_datetime(df[dt_col], errors="coerce")
print("Parsed datetime:", dt_col, " — nulls:", df["datetime"].isna().sum())

df = df[~df["datetime"].isna()].copy()
df = df.sort_values("datetime").reset_index(drop=True)

print("After datetime cleaning, rows:", len(df))
# Out:
# Parsed datetime: date  — nulls: 0
# After datetime cleaning, rows: 43848

# %%
pollutants = [
    "pm10","pm2_5","ammonia",
    "carbon_monoxide","nitrogen_dioxide",
    "carbon_dioxide","sulphur_dioxide","methane"
]

# try to fix common alternative column names
col_map = {}
for p in pollutants:
    if p not in df.columns:
        alternatives = [
            p.replace("_",""),
            p.replace("2_5","2.5"),
            p.replace("pm2_5","pm2.5"),
            p.replace("pm2_5","pm25"),
        ]
        for alt in alternatives:
            if alt in df.columns:
                col_map[alt] = p

if col_map:
    df = df.rename(columns=col_map)
    print("Renamed columns:", col_map)

missing = [p for p in pollutants if p not in df.columns]
if missing:
    print("Warning: Missing pollutant columns:", missing)

# convert to numeric
for p in pollutants:
    if p in df.columns:
        df[p] = (
            df[p].astype(str)
                 .str.replace("<","")
                 .str.replace(",","")
                 .str.strip()
        )
        df[p] = pd.to_numeric(df[p], errors="coerce")

# %%
# negative values → NaN
for p in pollutants:
    if p in df.columns:
        df.loc[df[p] < 0, p] = np.nan

# cap at 99.9 percentile (pollutant-dependent)
for p in pollutants:
    if p in df.columns:
        q = df[p].quantile(0.999)
        if pd.notna(q) and q > 0:
            df.loc[df[p] > q, p] = np.nan
        print(f"{p}: capped at {q}")
# Out:
# pm10: capped at 239.8791000000063
# pm2_5: capped at 166.53530000000245
# ammonia: capped at nan
# carbon_monoxide: capped at 12596.811000000227
# nitrogen_dioxide: capped at 253.8523000000052
# carbon_dioxide: capped at 594.353000000001
# sulphur_dioxide: capped at 119.3
# methane: capped at 2889.1190000000224

# %%
df = df.set_index("datetime")

start = df.index.min().ceil("H")
end   = df.index.max().floor("H")

full_idx = pd.date_range(start=start, end=end, freq="H")

df = df.reindex(full_idx)
print("Reindexed to hourly:", len(df))
# Out:
# Reindexed to hourly: 43848
# /tmp/ipython-input-1351569827.py:3: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   start = df.index.min().ceil("H")
# /tmp/ipython-input-1351569827.py:4: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   end   = df.index.max().floor("H")
# /tmp/ipython-input-1351569827.py:6: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   full_idx = pd.date_range(start=start, end=end, freq="H")

# %%
numeric_cols = [c for c in pollutants if c in df.columns]

df[numeric_cols] = df[numeric_cols].interpolate(method="time", limit=24)
df[numeric_cols] = df[numeric_cols].fillna(method="ffill", limit=6).fillna(method="bfill", limit=6)

print("Remaining NaNs:\n", df[numeric_cols].isna().sum())
# Out:
# /tmp/ipython-input-774743577.py:4: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[numeric_cols] = df[numeric_cols].fillna(method="ffill", limit=6).fillna(method="bfill", limit=6)
# Remaining NaNs:
#  pm10                14658
# pm2_5               14658
# ammonia             43848
# carbon_monoxide     14658
# nitrogen_dioxide    14658
# carbon_dioxide      34194
# sulphur_dioxide     14658
# methane             34194
# dtype: int64

# %%
df["missing_pollutants"] = df[numeric_cols].isna().sum(axis=1)

summary = df[numeric_cols].describe().T
summary["missing"] = df[numeric_cols].isna().sum()

summary
# Out:
#                     count         mean          std      min     25%     50%  \
# pm10              29190.0    67.823441    37.654796     0.50    38.4    61.9
# pm2_5             29190.0    51.279058    27.816707     0.40    29.7    46.4
# ammonia               0.0          NaN          NaN      NaN     NaN     NaN
# carbon_monoxide   29190.0  2154.864354  1654.089728     0.00   953.0  1687.0
# nitrogen_dioxide  29190.0    62.143052    39.278547     0.00    31.8    55.4
# carbon_dioxide     9654.0   466.254143    21.336038   435.00   451.0   460.0
# sulphur_dioxide   29190.0    41.898099    20.338757     0.25    26.5    39.5
# methane            9654.0  1702.474829   303.975739  1294.00  1469.0  1602.0
#
#                      75%      max  missing
# pm10                88.9    238.0    14658
# pm2_5               67.8    165.8    14658
# ammonia              NaN      NaN    43848
# carbon_monoxide   2886.0  12529.0    14658
# nitrogen_dioxide    82.8    252.3    14658
# carbon_dioxide     476.0    594.0    34194
# sulphur_dioxide     54.4    119.3    14658
# methane           1860.0   2881.0    34194

# %%
means = df[numeric_cols].mean(skipna=True)              # may contain NaN for pollutant with no valid data
ranking = means.reset_index()
ranking.columns = ["pollutant", "mean_value"]

# Split valid (finite means) and invalid (NaN means)
valid = ranking[ranking["mean_value"].notna()].copy()
invalid = ranking[ranking["mean_value"].isna()].copy()

# Rank only the valid ones (descending); convert to int safely
valid["rank"] = valid["mean_value"].rank(method="min", ascending=False).astype(int)

# For invalid ones, set rank to pandas NA (nullable Int) or a large number if you prefer
import pandas as pd
invalid["rank"] = pd.NA

# Combine back, put valid ranked items first
final_ranking = pd.concat([valid, invalid], ignore_index=True)
final_ranking = final_ranking.sort_values(by=["rank", "pollutant"], na_position="last").reset_index(drop=True)

print(final_ranking)

# Save cleaned hourly file and ranking
df.reset_index().rename(columns={"index":"datetime"}).to_csv("Jakarta_clean_hourly.csv", index=False)
final_ranking.to_csv("Jakarta_pollutant_ranking.csv", index=False)

print("Saved: Jakarta_clean_hourly.csv and Jakarta_pollutant_ranking.csv")
# Out:
#           pollutant   mean_value  rank
# 0   carbon_monoxide  2154.864354     1
# 1           methane  1702.474829     2
# 2    carbon_dioxide   466.254143     3
# 3              pm10    67.823441     4
# 4  nitrogen_dioxide    62.143052     5
# 5             pm2_5    51.279058     6
# 6   sulphur_dioxide    41.898099     7
# 7           ammonia          NaN  <NA>
# Saved: Jakarta_clean_hourly.csv and Jakarta_pollutant_ranking.csv

# %% [markdown]
# BANGKOK CLEANING

# %%
import pandas as pd
import numpy as np

# file name
fn = "Bangkok.csv"

df = pd.read_csv(fn)

print("shape:", df.shape)
print("columns:", df.columns.tolist())
print(df.head())
print("\nmissing per column:\n", df.isna().sum())
# Out:
# shape: (43848, 9)
# columns: ['date', 'pm10', 'pm2_5', 'ammonia', 'carbon_monoxide', 'nitrogen_dioxide', 'carbon_dioxide', 'sulphur_dioxide', 'methane']
#                         date  pm10  pm2_5  ammonia  carbon_monoxide  \
# 0  2020-12-01 00:00:00+00:00   NaN    NaN      NaN              NaN
# 1  2020-12-01 01:00:00+00:00   NaN    NaN      NaN              NaN
# 2  2020-12-01 02:00:00+00:00   NaN    NaN      NaN              NaN
# 3  2020-12-01 03:00:00+00:00   NaN    NaN      NaN              NaN
# 4  2020-12-01 04:00:00+00:00   NaN    NaN      NaN              NaN
#
#    nitrogen_dioxide  carbon_dioxide  sulphur_dioxide  methane
# 0               NaN             NaN              NaN      NaN
# 1               NaN             NaN              NaN      NaN
# 2               NaN             NaN              NaN      NaN
# 3               NaN             NaN              NaN      NaN
# 4               NaN             NaN              NaN      NaN
#
# missing per column:
#  date                    0
# pm10                14664
# pm2_5               14664
# ammonia             43848
# carbon_monoxide     14664
# nitrogen_dioxide    14664
# carbon_dioxide      34200
# sulphur_dioxide     14664
# methane             34200
# dtype: int64

# %%
df.columns = (
    df.columns.str.strip()
    .str.lower()
    .str.replace(" ", "_")
    .str.replace("-", "_")
)

print(df.columns.tolist())
# Out:
# ['date', 'pm10', 'pm2_5', 'ammonia', 'carbon_monoxide', 'nitrogen_dioxide', 'carbon_dioxide', 'sulphur_dioxide', 'methane']

# %%
candidates = ["datetime", "date_time", "date", "time", "timestamp"]

dt_col = None
for c in candidates:
    if c in df.columns:
        dt_col = c
        break

if dt_col is None:
    raise RuntimeError("No datetime column found. Rename your date column to datetime/date/date_time/etc.")

df["datetime"] = pd.to_datetime(df[dt_col], errors="coerce")

null_count = df["datetime"].isna().sum()
print(f"Parsed datetime column: '{dt_col}', null after parse = {null_count}")

df = df.dropna(subset=["datetime"]).copy()
df = df.sort_values("datetime").reset_index(drop=True)
# Out:
# Parsed datetime column: 'date', null after parse = 0

# %%
pollutants = [
    "pm10","pm2_5","ammonia","carbon_monoxide","nitrogen_dioxide",
    "carbon_dioxide","sulphur_dioxide","methane"
]

# attempt fixes for alternate names
col_map = {}
for p in pollutants:
    if p not in df.columns:
        alt = p.replace("_","").replace("2_5","2.5").replace("pm2_5","pm2.5")
        for candidate in [alt, alt.replace(".","_"), alt.replace(".","")]:
            if candidate in df.columns:
                col_map[candidate] = p

if col_map:
    df = df.rename(columns=col_map)
    print("Renamed:", col_map)

missing_cols = [p for p in pollutants if p not in df.columns]
if missing_cols:
    print("Missing pollutant columns:", missing_cols)

# convert to numeric
for p in pollutants:
    if p in df.columns:
        df[p] = (
            df[p].astype(str)
                 .str.replace("<","")
                 .str.replace(",","")
                 .str.strip()
        )
        df[p] = pd.to_numeric(df[p], errors="coerce")

# %%
for p in pollutants:
    if p in df.columns:
        df.loc[df[p] < 0, p] = np.nan

for p in pollutants:
    if p in df.columns:
        q = df[p].quantile(0.999)
        if pd.notna(q) and q > 0:
            df.loc[df[p] > q, p] = np.nan
        print(f"{p} cap at 99.9% =", q)
# Out:
# pm10 cap at 99.9% = 422.6353000000025
# pm2_5 cap at 99.9% = 294.3
# ammonia cap at 99.9% = nan
# carbon_monoxide cap at 99.9% = 10001.634000000005
# nitrogen_dioxide cap at 99.9% = 441.3916000000405
# carbon_dioxide cap at 99.9% = 541.706000000002
# sulphur_dioxide cap at 99.9% = 104.45850000000137
# methane cap at 99.9% = 2503.2410000000946

# %%
df = df.set_index("datetime")

start = df.index.min().ceil("H")
end   = df.index.max().floor("H")

full_idx = pd.date_range(start=start, end=end, freq="H")

df = df.reindex(full_idx)
print("Hourly reindex length:", len(df))
# Out:
# Hourly reindex length: 43848
# /tmp/ipython-input-2271776757.py:3: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   start = df.index.min().ceil("H")
# /tmp/ipython-input-2271776757.py:4: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   end   = df.index.max().floor("H")
# /tmp/ipython-input-2271776757.py:6: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   full_idx = pd.date_range(start=start, end=end, freq="H")

# %%
numeric_cols = [c for c in pollutants if c in df.columns]

df[numeric_cols] = df[numeric_cols].interpolate(method="time", limit=24)
df[numeric_cols] = df[numeric_cols].fillna(method="ffill", limit=6).fillna(method="bfill", limit=6)

print("Remaining NaNs:\n", df[numeric_cols].isna().sum())
# Out:
# Remaining NaNs:
#  pm10                14658
# pm2_5               14658
# ammonia             43848
# carbon_monoxide     14658
# nitrogen_dioxide    14658
# carbon_dioxide      34194
# sulphur_dioxide     14658
# methane             34194
# dtype: int64
# /tmp/ipython-input-774743577.py:4: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[numeric_cols] = df[numeric_cols].fillna(method="ffill", limit=6).fillna(method="bfill", limit=6)

# %%
df["n_missing_pollutants"] = df[numeric_cols].isna().sum(axis=1)
df[numeric_cols].describe().T
# Out:
#                     count         mean         std      min     25%     50%  \
# pm10              29190.0    43.345466   48.267980     0.80    15.9    27.2
# pm2_5             29190.0    31.587306   33.811850     0.60    11.6    20.5
# ammonia               0.0          NaN         NaN      NaN     NaN     NaN
# carbon_monoxide   29190.0   853.410432  931.728059     0.00   281.0   585.0
# nitrogen_dioxide  29190.0    30.817038   37.878544     0.00    10.1    18.1
# carbon_dioxide     9654.0   461.303398   13.852051   433.00   452.0   458.5
# sulphur_dioxide   29190.0    16.171508   14.672596     0.25     5.6    11.1
# methane            9654.0  1601.077118  177.144215  1315.00  1474.0  1562.0
#
#                      75%       max
# pm10                51.2    421.90
# pm2_5               38.5    294.30
# ammonia              NaN       NaN
# carbon_monoxide   1033.0  10000.00
# nitrogen_dioxide    35.9    429.30
# carbon_dioxide     467.0    541.00
# sulphur_dioxide     22.5    104.05
# methane           1681.0   2469.00

# %%
means = df[numeric_cols].mean(skipna=True)

ranking = means.reset_index()
ranking.columns = ["pollutant", "mean_value"]

valid = ranking[ranking["mean_value"].notna()].copy()
invalid = ranking[ranking["mean_value"].isna()].copy()

valid["rank"] = valid["mean_value"].rank(method="min", ascending=False).astype(int)
invalid["rank"] = pd.NA

final_ranking = pd.concat([valid, invalid], ignore_index=True)
final_ranking = final_ranking.sort_values(["rank", "pollutant"], na_position="last").reset_index(drop=True)

print(final_ranking)

df.reset_index().rename(columns={"index":"datetime"}).to_csv("Bangkok_clean_hourly.csv", index=False)
final_ranking.to_csv("Bangkok_pollutant_ranking.csv", index=False)

print("Saved: Bangkok_clean_hourly.csv & Bangkok_pollutant_ranking.csv")
# Out:
#           pollutant   mean_value  rank
# 0           methane  1601.077118     1
# 1   carbon_monoxide   853.410432     2
# 2    carbon_dioxide   461.303398     3
# 3              pm10    43.345466     4
# 4             pm2_5    31.587306     5
# 5  nitrogen_dioxide    30.817038     6
# 6   sulphur_dioxide    16.171508     7
# 7           ammonia          NaN  <NA>
# Saved: Bangkok_clean_hourly.csv & Bangkok_pollutant_ranking.csv

# %% [markdown]
# TOKYO CLEANING

# %%
import pandas as pd
import numpy as np

fn = "Tokyo.csv"
df = pd.read_csv(fn)

print("shape:", df.shape)
print("columns:", df.columns.tolist())
print(df.head(5))
print("\nMissing per column:\n", df.isna().sum())
# Out:
# shape: (43848, 9)
# columns: ['date', 'pm10', 'pm2_5', 'ammonia', 'carbon_monoxide', 'nitrogen_dioxide', 'carbon_dioxide', 'sulphur_dioxide', 'methane']
#                         date  pm10  pm2_5  ammonia  carbon_monoxide  \
# 0  2020-12-01 00:00:00+00:00   NaN    NaN      NaN              NaN
# 1  2020-12-01 01:00:00+00:00   NaN    NaN      NaN              NaN
# 2  2020-12-01 02:00:00+00:00   NaN    NaN      NaN              NaN
# 3  2020-12-01 03:00:00+00:00   NaN    NaN      NaN              NaN
# 4  2020-12-01 04:00:00+00:00   NaN    NaN      NaN              NaN
#
#    nitrogen_dioxide  carbon_dioxide  sulphur_dioxide  methane
# 0               NaN             NaN              NaN      NaN
# 1               NaN             NaN              NaN      NaN
# 2               NaN             NaN              NaN      NaN
# 3               NaN             NaN              NaN      NaN
# 4               NaN             NaN              NaN      NaN
#
# Missing per column:
#  date                    0
# pm10                14664
# pm2_5               14664
# ammonia             43848
# carbon_monoxide     14664
# nitrogen_dioxide    14664
# carbon_dioxide      34200
# sulphur_dioxide     14664
# methane             34200
# dtype: int64

# %%
df.columns = (
    df.columns.str.strip()
              .str.lower()
              .str.replace(" ", "_", regex=False)
              .str.replace("-", "_", regex=False)
)

print(df.columns.tolist())
# Out:
# ['date', 'pm10', 'pm2_5', 'ammonia', 'carbon_monoxide', 'nitrogen_dioxide', 'carbon_dioxide', 'sulphur_dioxide', 'methane']

# %%
candidates = ["datetime", "date_time", "date", "time", "timestamp"]
dt_col = next((c for c in candidates if c in df.columns), None)

if dt_col is None:
    raise RuntimeError("No datetime column found. Rename your date/time column to one of: " + ", ".join(candidates))

df["datetime"] = pd.to_datetime(df[dt_col], errors="coerce")
print(f"Parsed datetime column: '{dt_col}' — null after parse = {df['datetime'].isna().sum()}")

df = df.dropna(subset=["datetime"]).copy()
df = df.sort_values("datetime").reset_index(drop=True)
print("Rows after datetime cleaning:", len(df))
# Out:
# Parsed datetime column: 'date' — null after parse = 0
# Rows after datetime cleaning: 43848

# %%
pollutants = [
    "pm10","pm2_5","ammonia","carbon_monoxide",
    "nitrogen_dioxide","carbon_dioxide","sulphur_dioxide","methane"
]

# map common variants (pm2.5, pm25, etc.) to pm2_5
col_map = {}
for p in pollutants:
    if p not in df.columns:
        alternatives = [
            p.replace("_",""),
            p.replace("2_5","2.5"),
            p.replace("pm2_5","pm2.5"),
            "pm25","pm2.5"
        ]
        for alt in alternatives:
            if alt in df.columns:
                col_map[alt] = p

if col_map:
    df = df.rename(columns=col_map)
    print("Renamed columns:", col_map)

missing = [p for p in pollutants if p not in df.columns]
if missing:
    print("Warning — missing pollutant columns:", missing)

# convert to numeric and clean strings like "<1" or "1,234"
for p in pollutants:
    if p in df.columns:
        df[p] = (
            df[p].astype(str)
                 .str.replace("<", "", regex=False)
                 .str.replace(",", "", regex=False)
                 .str.strip()
        )
        df[p] = pd.to_numeric(df[p], errors="coerce")

# %%
for p in pollutants:
    if p in df.columns:
        df.loc[df[p] < 0, p] = np.nan

for p in pollutants:
    if p in df.columns:
        q = df[p].quantile(0.999)
        if pd.notna(q) and q > 0:
            df.loc[df[p] > q, p] = np.nan
        print(f"{p}: 99.9% cap = {q}")
# Out:
# pm10: 99.9% cap = 162.1
# pm2_5: 99.9% cap = 116.36340000000055
# ammonia: 99.9% cap = nan
# carbon_monoxide: 99.9% cap = 1458.1700000000274
# nitrogen_dioxide: 99.9% cap = 196.4
# carbon_dioxide: 99.9% cap = 730.4120000000039
# sulphur_dioxide: 99.9% cap = 248.61700000000275
# methane: 99.9% cap = 1723.059000000003

# %%
df = df.set_index("datetime")

start = df.index.min().ceil("H")
end   = df.index.max().floor("H")

full_idx = pd.date_range(start=start, end=end, freq="H")

df = df.reindex(full_idx)
print("Reindexed hourly — new length:", len(df))
# Out:
# Reindexed hourly — new length: 43848
# /tmp/ipython-input-2946176890.py:3: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   start = df.index.min().ceil("H")
# /tmp/ipython-input-2946176890.py:4: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   end   = df.index.max().floor("H")
# /tmp/ipython-input-2946176890.py:6: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   full_idx = pd.date_range(start=start, end=end, freq="H")

# %%
numeric_cols = [c for c in pollutants if c in df.columns]

df[numeric_cols] = df[numeric_cols].interpolate(method="time", limit=24)
df[numeric_cols] = df[numeric_cols].fillna(method="ffill", limit=6).fillna(method="bfill", limit=6)

print("Remaining NaNs per pollutant:\n", df[numeric_cols].isna().sum())
# Out:
# Remaining NaNs per pollutant:
#  pm10                14658
# pm2_5               14658
# ammonia             43848
# carbon_monoxide     14658
# nitrogen_dioxide    14658
# carbon_dioxide      34194
# sulphur_dioxide     14658
# methane             34194
# dtype: int64
# /tmp/ipython-input-1757015156.py:4: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[numeric_cols] = df[numeric_cols].fillna(method="ffill", limit=6).fillna(method="bfill", limit=6)

# %%
df["n_missing_pollutants"] = df[numeric_cols].isna().sum(axis=1)
summary = df[numeric_cols].describe().T
summary["missing_count"] = df[numeric_cols].isna().sum()
summary
# Out:
#                     count         mean         std     min     25%     50%  \
# pm10              29190.0    33.834018   23.954769     0.6    17.2    27.3
# pm2_5             29190.0    24.847945   17.778309     0.4    12.4    19.8
# ammonia               0.0          NaN         NaN     NaN     NaN     NaN
# carbon_monoxide   29190.0   337.056355  181.795319    59.0   219.0   286.0
# nitrogen_dioxide  29190.0    50.398136   26.638013     0.0    29.5    47.9
# carbon_dioxide     9654.0   478.722706   36.116151   433.0   456.0   467.0
# sulphur_dioxide   29190.0    30.453808   29.666070     0.0    11.9    22.0
# methane            9654.0  1463.324011   69.660656  1318.0  1415.0  1449.0
#
#                      75%     max  missing_count
# pm10                43.1   162.1          14658
# pm2_5               32.0   116.2          14658
# ammonia              NaN     NaN          43848
# carbon_monoxide    399.0  1450.0          14658
# nitrogen_dioxide    67.4   196.4          14658
# carbon_dioxide     488.0   729.0          34194
# sulphur_dioxide     38.9   247.8          14658
# methane           1502.0  1722.0          34194

# %%
means = df[numeric_cols].mean(skipna=True)
ranking = means.reset_index()
ranking.columns = ["pollutant", "mean_value"]

# separate valid and invalid means
valid = ranking[ranking["mean_value"].notna()].copy()
invalid = ranking[ranking["mean_value"].isna()].copy()

valid["rank"] = valid["mean_value"].rank(method="min", ascending=False).astype(int)
invalid["rank"] = pd.NA

final_ranking = pd.concat([valid, invalid], ignore_index=True)
final_ranking = final_ranking.sort_values(["rank","pollutant"], na_position="last").reset_index(drop=True)

print(final_ranking)

# Save cleaned hourly and ranking
df.reset_index().rename(columns={"index":"datetime"}).to_csv("Tokyo_clean_hourly.csv", index=False)
final_ranking.to_csv("Tokyo_pollutant_ranking.csv", index=False)

print("Saved: Tokyo_clean_hourly.csv and Tokyo_pollutant_ranking.csv")
# Out:
#           pollutant   mean_value  rank
# 0           methane  1463.324011     1
# 1    carbon_dioxide   478.722706     2
# 2   carbon_monoxide   337.056355     3
# 3  nitrogen_dioxide    50.398136     4
# 4              pm10    33.834018     5
# 5   sulphur_dioxide    30.453808     6
# 6             pm2_5    24.847945     7
# 7           ammonia          NaN  <NA>
# Saved: Tokyo_clean_hourly.csv and Tokyo_pollutant_ranking.csv

# %% [markdown]
# CLUSTERING PROCESS (HIERARCHICAL CLUSTERING)

# %%
import pandas as pd

# Load each city’s pollutant mean file
jak = pd.read_csv("Jakarta_pollutant_ranking.csv")
ban = pd.read_csv("Bangkok_pollutant_ranking.csv")
tok = pd.read_csv("Tokyo_pollutant_ranking.csv")

# Add city names
jak["city"] = "Jakarta"
ban["city"] = "Bangkok"
tok["city"] = "Tokyo"

# Combine into one table
df_means = pd.concat([jak, ban, tok], ignore_index=True)

df_means
# Out:
#            pollutant   mean_value  rank     city
# 0    carbon_monoxide  2154.864354   1.0  Jakarta
# 1            methane  1702.474829   2.0  Jakarta
# 2     carbon_dioxide   466.254143   3.0  Jakarta
# 3               pm10    67.823441   4.0  Jakarta
# 4   nitrogen_dioxide    62.143052   5.0  Jakarta
# 5              pm2_5    51.279058   6.0  Jakarta
# 6    sulphur_dioxide    41.898099   7.0  Jakarta
# 7            ammonia          NaN   NaN  Jakarta
# 8            methane  1601.077118   1.0  Bangkok
# 9    carbon_monoxide   853.410432   2.0  Bangkok
# 10    carbon_dioxide   461.303398   3.0  Bangkok
# 11              pm10    43.345466   4.0  Bangkok
# 12             pm2_5    31.587306   5.0  Bangkok
# 13  nitrogen_dioxide    30.817038   6.0  Bangkok
# 14   sulphur_dioxide    16.171508   7.0  Bangkok
# 15           ammonia          NaN   NaN  Bangkok
# 16           methane  1463.324011   1.0    Tokyo
# 17    carbon_dioxide   478.722706   2.0    Tokyo
# 18   carbon_monoxide   337.056355   3.0    Tokyo
# 19  nitrogen_dioxide    50.398136   4.0    Tokyo
# 20              pm10    33.834018   5.0    Tokyo
# 21   sulphur_dioxide    30.453808   6.0    Tokyo
# 22             pm2_5    24.847945   7.0    Tokyo
# 23           ammonia          NaN   NaN    Tokyo

# %%
df_city = df_means.pivot(index="city", columns="pollutant", values="mean_value")

df_city
# Out:
# pollutant  ammonia  carbon_dioxide  carbon_monoxide      methane  \
# city
# Bangkok        NaN      461.303398       853.410432  1601.077118
# Jakarta        NaN      466.254143      2154.864354  1702.474829
# Tokyo          NaN      478.722706       337.056355  1463.324011
#
# pollutant  nitrogen_dioxide       pm10      pm2_5  sulphur_dioxide
# city
# Bangkok           30.817038  43.345466  31.587306        16.171508
# Jakarta           62.143052  67.823441  51.279058        41.898099
# Tokyo             50.398136  33.834018  24.847945        30.453808

# %%
import numpy as np
import pandas as pd

try:
    df_city
except NameError:
    # replace filename if needed
    df_city = pd.read_csv("df_city.csv", index_col=0)

print("Original df_city:\n")
display(df_city)

# Replace inf with NaN
df_city = df_city.replace([np.inf, -np.inf], np.nan)

# Show NaN summary
print("\nNaN per column before cleaning:")
print(df_city.isna().sum())

# Drop columns that are entirely NaN (like ammonia)
all_nan_cols = df_city.columns[df_city.isna().all()].tolist()
if all_nan_cols:
    print("\nDropping columns with all NaN:", all_nan_cols)
    df_city = df_city.drop(columns=all_nan_cols)

# If any columns have many NaNs (>80%) drop them:
too_many = df_city.columns[df_city.isna().mean() > 0.8].tolist()
if too_many:
    print("Dropping columns with >80% NaN:", too_many)
    df_city = df_city.drop(columns=too_many)

# Impute remaining NaNs with column median (safe for small table)
if df_city.isna().any().any():
    print("Imputing remaining NaNs with column median.")
    df_city = df_city.fillna(df_city.median())

print("\nPost-cleaning df_city:")
display(df_city)
# Out:
# Original df_city:
# pollutant  ammonia  carbon_dioxide  carbon_monoxide      methane  \
# city
# Bangkok        NaN      461.303398       853.410432  1601.077118
# Jakarta        NaN      466.254143      2154.864354  1702.474829
# Tokyo          NaN      478.722706       337.056355  1463.324011
#
# pollutant  nitrogen_dioxide       pm10      pm2_5  sulphur_dioxide
# city
# Bangkok           30.817038  43.345466  31.587306        16.171508
# Jakarta           62.143052  67.823441  51.279058        41.898099
# Tokyo             50.398136  33.834018  24.847945        30.453808
# NaN per column before cleaning:
# pollutant
# ammonia             3
# carbon_dioxide      0
# carbon_monoxide     0
# methane             0
# nitrogen_dioxide    0
# pm10                0
# pm2_5               0
# sulphur_dioxide     0
# dtype: int64
#
# Dropping columns with all NaN: ['ammonia']
#
# Post-cleaning df_city:
# pollutant  carbon_dioxide  carbon_monoxide      methane  nitrogen_dioxide  \
# city
# Bangkok        461.303398       853.410432  1601.077118         30.817038
# Jakarta        466.254143      2154.864354  1702.474829         62.143052
# Tokyo          478.722706       337.056355  1463.324011         50.398136
#
# pollutant       pm10      pm2_5  sulphur_dioxide
# city
# Bangkok    43.345466  31.587306        16.171508
# Jakarta    67.823441  51.279058        41.898099
# Tokyo      33.834018  24.847945        30.453808

# %%
from sklearn.preprocessing import StandardScaler
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster
import matplotlib.pyplot as plt

# convert to float matrix
X = df_city.values.astype(float)

# Standardize
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# linkage
Z = linkage(X_scaled, method="ward")

# plot dendrogram
plt.figure(figsize=(6,4))
dendrogram(Z, labels=df_city.index.tolist(), leaf_rotation=0, leaf_font_size=12)
plt.title("Hierarchical clustering (Ward) — Asian cities")
plt.ylabel("Linkage distance")
plt.tight_layout()
plt.show()

# assign cluster labels (choose k, e.g., 2)
k = 2
labels = fcluster(Z, t=k, criterion="maxclust")
df_city["cluster"] = labels
print("\nAssigned clusters:")
display(df_city[["cluster"]])
# Out:
# Assigned clusters:
# pollutant  cluster
# city
# Bangkok          1
# Jakarta          2
# Tokyo            1

# %%
import seaborn as sns
plt.figure(figsize=(7,4))
# use standardized values for heatmap to show relative differences
X_scaled_df = pd.DataFrame(X_scaled, index=df_city.index, columns=df_city.columns[:-1] if "cluster" in df_city.columns else df_city.columns)
sns.heatmap(X_scaled_df, annot=True, fmt=".2f", cmap="vlag", cbar_kws={"label": "z-score"})
plt.title("Standardized pollutant means (Asian cities)")
plt.ylabel("City")
plt.xlabel("Pollutant")
plt.tight_layout()
plt.show()
